# %% [markdown]
# # VGG16 모델 활용 이미지 식별 모델
# - data : cifar10

# %%
from tensorflow.keras.datasets.cifar10 import load_data
from tensorflow.keras.utils import set_random_seed, plot_model
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, Flatten, MaxPool2D, Input
from keras.applications.vgg16 import preprocess_input, decode_predictions, VGG16
from tensorflow import random
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np

# %%
(x_train, y_train), (x_test, y_test)=load_data()

# %%
# x_train, x_val, y_train, y_val=train_test_split(
# x_train, y_train, stratify=y_train, test_size=0.2, random_state=42)

# %%
# 스케일링
x_train=x_train/255.0
x_test=x_test/255.0
#x_val=x_val/255.0

# %% [markdown]
# ## 모델

# %%
x_train.shape, x_test.shape
# Out:
# ((50000, 32, 32, 3), (10000, 32, 32, 3))

# %%
input_tensor=Input(shape=(32, 32, 3))

# %%
model=VGG16(weights='imagenet', include_top=False, input_tensor=input_tensor)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 4s 0us/step

# %%
plot_model(model, show_shapes=True)

# %%
model.layers
# Out:
# [<keras.engine.input_layer.InputLayer at 0x1c3ce2cdbb0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1c431ddb190>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1c3cde47a60>,
#  <keras.layers.pooling.max_pooling2d.MaxPooling2D at 0x1c431dd9d90>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1c431dd2be0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1c431dcccd0>,
#  <keras.layers.pooling.max_pooling2d.MaxPooling2D at 0x1c3ce5bbd90>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1c3ce66bd30>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1c431dde130>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1c431dd8f40>,
#  <keras.layers.pooling.max_pooling2d.MaxPooling2D at 0x1c431dd92e0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1c431ddb460>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1c431dda340>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1c431dccfd0>,
#  <keras.layers.pooling.max_pooling2d.MaxPooling2D at 0x1c431dec8b0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1c431dd25e0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1c431dede80>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x1c431df9070>,
#  <keras.layers.pooling.max_pooling2d.MaxPooling2D at 0x1c431df3c40>]

# %%
layer_dict = dict([(layer.name, layer) for layer in model.layers])

# %%
layer_dict
# Out:
# {'input_5': <keras.engine.input_layer.InputLayer at 0x1c3ce2cdbb0>,
#  'block1_conv1': <keras.layers.convolutional.conv2d.Conv2D at 0x1c431ddb190>,
#  'block1_conv2': <keras.layers.convolutional.conv2d.Conv2D at 0x1c3cde47a60>,
#  'block1_pool': <keras.layers.pooling.max_pooling2d.MaxPooling2D at 0x1c431dd9d90>,
#  'block2_conv1': <keras.layers.convolutional.conv2d.Conv2D at 0x1c431dd2be0>,
#  'block2_conv2': <keras.layers.convolutional.conv2d.Conv2D at 0x1c431dcccd0>,
#  'block2_pool': <keras.layers.pooling.max_pooling2d.MaxPooling2D at 0x1c3ce5bbd90>,
#  'block3_conv1': <keras.layers.convolutional.conv2d.Conv2D at 0x1c3ce66bd30>,
#  'block3_conv2': <keras.layers.convolutional.conv2d.Conv2D at 0x1c431dde130>,
#  'block3_conv3': <keras.layers.convolutional.conv2d.Conv2D at 0x1c431dd8f40>,
#  'block3_pool': <keras.layers.pooling.max_pooling2d.MaxPooling2D at 0x1c431dd92e0>,
#  'block4_conv1': <keras.layers.convolutional.conv2d.Conv2D at 0x1c431ddb460>,
#  'block4_conv2': <keras.layers.convolutional.conv2d.Conv2D at 0x1c431dda340>,
#  'block4_conv3': <keras.layers.convolutional.conv2d.Conv2D at 0x1c431dccfd0>,
#  'block4_pool': <keras.layers.pooling.max_pooling2d.MaxPooling2D at 0x1c431dec8b0>,
#  'block5_conv1': <keras.layers.convolutional.conv2d.Conv2D at 0x1c431dd25e0>,
#  'block5_conv2': <keras.layers.convolutional.conv2d.Conv2D at 0x1c431dede80>,
#  'block5_conv3': <keras.layers.convolutional.conv2d.Conv2D at 0x1c431df9070>,
#  'block5_pool': <keras.layers.pooling.max_pooling2d.MaxPooling2D at 0x1c431df3c40>}

# %%
x=layer_dict['block5_pool'].output

# %%
x=Conv2D(filters=64, kernel_size=(3, 3), activation='relu')(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [51], in <cell line: 1>()
# ----> 1 x=Conv2D(filters=64, kernel_size=(3, 3), activation='relu')(x)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\utils\traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File ~\AppData\Roaming\Python\Python39\site-packages\keras\layers\convolutional\base_conv.py:307, in Conv.compute_output_shape(self, input_shape)
#     302     return tf.TensorShape(
#     303         input_shape[:batch_rank] + [self.filters] +
#     304         self._spatial_output_shape(input_shape[batch_rank + 1:]))
#     306 except ValueError:
# --> 307   raise ValueError(
#     308       f'One of the dimensions in the output is <= 0 '
#     309       f'due to downsampling in {self.name}. Consider '
#     310       f'increasing the input size. '
#     311       f'Received input shape {input_shape} which would produce '
#     312       f'output shape with a zero or negative value in a '
#     313       f'dimension.')
#
# ValueError: One of the dimensions in the output is <= 0 due to downsampling in conv2d. Consider increasing the input size. Received input shape [None, 1, 1, 512] which would produce output shape with a zero or negative value in a dimension.
