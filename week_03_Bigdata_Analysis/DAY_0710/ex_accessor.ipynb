# %% [markdown]
# # 접근자(Accessor)
#
# - DF/SR에 속성으로 제공되며 다른 객체의 기능/속성을 사용할 수 있도록 해줌
#
# - 종류
#     - Series.dt : datetime 관련 속성 사용할 수 있도록 해줌
#     - Series.str : string 관련 메서드 사용할 수 있도록 해줌
#     - DataFrame.spare : spare 관련 속성/메서드 사용할 수 있도록 해줌

# %%
# 모듈 로딩
import pandas as pd
import random

# 데이터생성 ---------------------------------------
# 이름, 생년월일, 나이 3개 컬럼으로 구성 
# 총 10명, 생일이 한 달 차이로 일자는 똑같도록
# 이름은 영문 (ex: Tom Kim)
df=pd.DataFrame({'name':['Tom Kim', 'Mab Lee', 'Mat Park', 'Michael Kim', 'Gildong Hong', 'Jaesuck You', 'Red Park', 'Yellow Kim', 'Blue Lee', 'Purple Choi'],
                'birth':pd.date_range('2012-01-07', periods=10, freq='M'),
                'age':[random.randint(17, 25) for num in range(10)]})

# %%
df
# Out:
#            name      birth  age
# 0       Tom Kim 2012-01-31   19
# 1       Mab Lee 2012-02-29   20
# 2      Mat Park 2012-03-31   19
# 3   Michael Kim 2012-04-30   19
# 4  Gildong Hong 2012-05-31   17
# 5   Jaesuck You 2012-06-30   20
# 6      Red Park 2012-07-31   17
# 7    Yellow Kim 2012-08-31   23
# 8      Blue Lee 2012-09-30   21
# 9   Purple Choi 2012-10-31   18

# %%
# name 컬럼의 이름을 분리하기
df['name'].str.split()
# Out:
# 0         [Tom, Kim]
# 1         [Mab, Lee]
# 2        [Mat, Park]
# 3     [Michael, Kim]
# 4    [Gildong, Hong]
# 5     [Jaesuck, You]
# 6        [Red, Park]
# 7      [Yellow, Kim]
# 8        [Blue, Lee]
# 9     [Purple, Choi]
# Name: name, dtype: object

# %%
# name 컬럼의 이름을 모두 대문자로 바꾸고 싶음
df['name'].str.upper()
# Out:
# 0         TOM KIM
# 1         MAB LEE
# 2        MAT PARK
# 3     MICHAEL KIM
# 4    GILDONG HONG
# 5     JAESUCK YOU
# 6        RED PARK
# 7      YELLOW KIM
# 8        BLUE LEE
# 9     PURPLE CHOI
# Name: name, dtype: object

# %%
# 각각의 이름 안에 a가 포함되어 있는지가 궁금함
df['name'].str.contains('a')
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False
# 5     True
# 6     True
# 7    False
# 8    False
# 9    False
# Name: name, dtype: bool

# %% [markdown]
# ## str 데이터로 구성된 컬럼(Series)의 str 접근자
#
# - 전체 컬럼의 요소에 str 관련 메서드 사용 가능하도록 하는 접근자
# - 사용법
#     - 객체변수[컬럼명].str.메서드() => upper, lower, split, ...
#     - 객체변수[컬럼명].str.get(인덱스) => 분리 문자리스트에서 특정 요소 추출

# %%
# 문자열 분리
flname=df['name'].str.split()

# %%
# 내가 한 방법
#df['first_name']=pd.DataFrame([df['name'].str.split()[idx][0] for idx in df.index])

# %%
df
# Out:
#            name      birth  age
# 0       Tom Kim 2012-01-31   19
# 1       Mab Lee 2012-02-29   20
# 2      Mat Park 2012-03-31   19
# 3   Michael Kim 2012-04-30   19
# 4  Gildong Hong 2012-05-31   17
# 5   Jaesuck You 2012-06-30   20
# 6      Red Park 2012-07-31   17
# 7    Yellow Kim 2012-08-31   23
# 8      Blue Lee 2012-09-30   21
# 9   Purple Choi 2012-10-31   18

# %%
# 내가 한 방법
#df['second_name']=pd.DataFrame([df['name'].str.split()[idx][1] for idx in df.index])

# %%
df
# Out:
#            name      birth  age
# 0       Tom Kim 2012-01-31   19
# 1       Mab Lee 2012-02-29   20
# 2      Mat Park 2012-03-31   19
# 3   Michael Kim 2012-04-30   19
# 4  Gildong Hong 2012-05-31   17
# 5   Jaesuck You 2012-06-30   20
# 6      Red Park 2012-07-31   17
# 7    Yellow Kim 2012-08-31   23
# 8      Blue Lee 2012-09-30   21
# 9   Purple Choi 2012-10-31   18

# %%
# 분리된 문자열 리스트에서 특정 값 가져오기
flname.str.get(0)
# Out:
# 0        Tom
# 1        Mab
# 2        Mat
# 3    Michael
# 4    Gildong
# 5    Jaesuck
# 6        Red
# 7     Yellow
# 8       Blue
# 9     Purple
# Name: name, dtype: object

# %%
flname.str.get(1)
# Out:
# 0     Kim
# 1     Lee
# 2    Park
# 3     Kim
# 4    Hong
# 5     You
# 6    Park
# 7     Kim
# 8     Lee
# 9    Choi
# Name: name, dtype: object

# %%
df['first_name']=flname.str.get(0)
df['last_name']=flname.str.get(1)
df
# Out:
#            name      birth  age first_name last_name
# 0       Tom Kim 2012-01-31   19        Tom       Kim
# 1       Mab Lee 2012-02-29   20        Mab       Lee
# 2      Mat Park 2012-03-31   19        Mat      Park
# 3   Michael Kim 2012-04-30   19    Michael       Kim
# 4  Gildong Hong 2012-05-31   17    Gildong      Hong
# 5   Jaesuck You 2012-06-30   20    Jaesuck       You
# 6      Red Park 2012-07-31   17        Red      Park
# 7    Yellow Kim 2012-08-31   23     Yellow       Kim
# 8      Blue Lee 2012-09-30   21       Blue       Lee
# 9   Purple Choi 2012-10-31   18     Purple      Choi

# %%
# str.split()
# expand=True로 넣으면 전부 컬럼으로 만들어짐
value=df['name'].str.split(expand=True)
type(value)
# Out:
# pandas.core.frame.DataFrame

# %%
# value의 컬럼 이름 변경
value.columns=['first_name_2', 'last_name_2']

# %%
df=pd.concat([df, value], axis=1)

# %%
df
# Out:
#            name      birth  age first_name last_name first_name_2 last_name_2
# 0       Tom Kim 2012-01-31   19        Tom       Kim          Tom         Kim
# 1       Mab Lee 2012-02-29   20        Mab       Lee          Mab         Lee
# 2      Mat Park 2012-03-31   19        Mat      Park          Mat        Park
# 3   Michael Kim 2012-04-30   19    Michael       Kim      Michael         Kim
# 4  Gildong Hong 2012-05-31   17    Gildong      Hong      Gildong        Hong
# 5   Jaesuck You 2012-06-30   20    Jaesuck       You      Jaesuck         You
# 6      Red Park 2012-07-31   17        Red      Park          Red        Park
# 7    Yellow Kim 2012-08-31   23     Yellow       Kim       Yellow         Kim
# 8      Blue Lee 2012-09-30   21       Blue       Lee         Blue         Lee
# 9   Purple Choi 2012-10-31   18     Purple      Choi       Purple        Choi

# %%
# 특정 컬럼 이름만 변경하기
df.rename(columns={'first_name_2':'F_N', 'last_name_2':'L_N'}, inplace=True)

# %%
df
# Out:
#            name      birth  age first_name last_name      F_N   L_N
# 0       Tom Kim 2012-01-31   19        Tom       Kim      Tom   Kim
# 1       Mab Lee 2012-02-29   20        Mab       Lee      Mab   Lee
# 2      Mat Park 2012-03-31   19        Mat      Park      Mat  Park
# 3   Michael Kim 2012-04-30   19    Michael       Kim  Michael   Kim
# 4  Gildong Hong 2012-05-31   17    Gildong      Hong  Gildong  Hong
# 5   Jaesuck You 2012-06-30   20    Jaesuck       You  Jaesuck   You
# 6      Red Park 2012-07-31   17        Red      Park      Red  Park
# 7    Yellow Kim 2012-08-31   23     Yellow       Kim   Yellow   Kim
# 8      Blue Lee 2012-09-30   21       Blue       Lee     Blue   Lee
# 9   Purple Choi 2012-10-31   18     Purple      Choi   Purple  Choi

# %% [markdown]
# ## 실습
# - stock-data.csv
# - 접근자 사용하여 Date 컬럼 분할(Y, M, D)
# - D일 기준으로 정렬

# %%
# stock-data.csv => Date 컬럼을 연, 월, 일 따로 컬럼 추가
stock=pd.read_csv('../Data/stock-data.csv')
stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    20 non-null     object
#  1   Close   20 non-null     int64
#  2   Start   20 non-null     int64
#  3   High    20 non-null     int64
#  4   Low     20 non-null     int64
#  5   Volume  20 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 1.1+ KB

# %%
#stock['Date']=pd.to_datetime(stock['Date'])
# 먼저 바꾸니까 .str 안써짐,,
stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    20 non-null     object
#  1   Close   20 non-null     int64
#  2   Start   20 non-null     int64
#  3   High    20 non-null     int64
#  4   Low     20 non-null     int64
#  5   Volume  20 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 1.1+ KB

# %%
date_split=stock['Date'].str.split('-')
date_split
# Out:
# 0     [2018, 07, 02]
# 1     [2018, 06, 29]
# 2     [2018, 06, 28]
# 3     [2018, 06, 27]
# 4     [2018, 06, 26]
# 5     [2018, 06, 25]
# 6     [2018, 06, 22]
# 7     [2018, 06, 21]
# 8     [2018, 06, 20]
# 9     [2018, 06, 19]
# 10    [2018, 06, 18]
# 11    [2018, 06, 15]
# 12    [2018, 06, 14]
# 13    [2020, 06, 12]
# 14    [2020, 06, 11]
# 15    [2020, 06, 08]
# 16    [2021, 06, 07]
# 17    [2022, 06, 05]
# 18    [2022, 06, 04]
# 19    [2022, 06, 01]
# Name: Date, dtype: object

# %%
stock['Year']=date_split.str.get(0)
stock['Month']=date_split.str.get(1)
stock['Day']=date_split.str.get(2)

# %%
stock
# Out:
#           Date  Close  Start   High    Low  Volume  Year Month Day
# 0   2018-07-02  10100  10850  10900  10000  137977  2018    07  02
# 1   2018-06-29  10700  10550  10900   9990  170253  2018    06  29
# 2   2018-06-28  10400  10900  10950  10150  155769  2018    06  28
# 3   2018-06-27  10900  10800  11050  10500  133548  2018    06  27
# 4   2018-06-26  10800  10900  11000  10700   63039  2018    06  26
# 5   2018-06-25  11150  11400  11450  11000   55519  2018    06  25
# 6   2018-06-22  11300  11250  11450  10750  134805  2018    06  22
# 7   2018-06-21  11200  11350  11750  11200  133002  2018    06  21
# 8   2018-06-20  11550  11200  11600  10900  308596  2018    06  20
# 9   2018-06-19  11300  11850  11950  11300  180656  2018    06  19
# 10  2018-06-18  12000  13400  13400  12000  309787  2018    06  18
# 11  2018-06-15  13400  13600  13600  12900  201376  2018    06  15
# 12  2018-06-14  13450  13200  13700  13150  347451  2018    06  14
# 13  2020-06-12  13200  12200  13300  12050  558148  2020    06  12
# 14  2020-06-11  11950  12000  12250  11950   62293  2020    06  11
# 15  2020-06-08  11950  11950  12200  11800   59258  2020    06  08
# 16  2021-06-07  11950  12200  12300  11900   49088  2021    06  07
# 17  2022-06-05  12150  11800  12250  11800   42485  2022    06  05
# 18  2022-06-04  11900  11900  12200  11700   25171  2022    06  04
# 19  2022-06-01  11900  11800  12100  11750   32062  2022    06  01

# %%
stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    20 non-null     object
#  1   Close   20 non-null     int64
#  2   Start   20 non-null     int64
#  3   High    20 non-null     int64
#  4   Low     20 non-null     int64
#  5   Volume  20 non-null     int64
#  6   Year    20 non-null     object
#  7   Month   20 non-null     object
#  8   Day     20 non-null     object
# dtypes: int64(5), object(4)
# memory usage: 1.5+ KB

# %%
stock.sort_values(by=['Day'], inplace=True)

# %%
stock
# Out:
#           Date  Close  Start   High    Low  Volume  Year Month Day
# 19  2022-06-01  11900  11800  12100  11750   32062  2022    06  01
# 0   2018-07-02  10100  10850  10900  10000  137977  2018    07  02
# 18  2022-06-04  11900  11900  12200  11700   25171  2022    06  04
# 17  2022-06-05  12150  11800  12250  11800   42485  2022    06  05
# 16  2021-06-07  11950  12200  12300  11900   49088  2021    06  07
# 15  2020-06-08  11950  11950  12200  11800   59258  2020    06  08
# 14  2020-06-11  11950  12000  12250  11950   62293  2020    06  11
# 13  2020-06-12  13200  12200  13300  12050  558148  2020    06  12
# 12  2018-06-14  13450  13200  13700  13150  347451  2018    06  14
# 11  2018-06-15  13400  13600  13600  12900  201376  2018    06  15
# 10  2018-06-18  12000  13400  13400  12000  309787  2018    06  18
# 9   2018-06-19  11300  11850  11950  11300  180656  2018    06  19
# 8   2018-06-20  11550  11200  11600  10900  308596  2018    06  20
# 7   2018-06-21  11200  11350  11750  11200  133002  2018    06  21
# 6   2018-06-22  11300  11250  11450  10750  134805  2018    06  22
# 5   2018-06-25  11150  11400  11450  11000   55519  2018    06  25
# 4   2018-06-26  10800  10900  11000  10700   63039  2018    06  26
# 3   2018-06-27  10900  10800  11050  10500  133548  2018    06  27
# 2   2018-06-28  10400  10900  10950  10150  155769  2018    06  28
# 1   2018-06-29  10700  10550  10900   9990  170253  2018    06  29

# %% [markdown]
# #### expand 쓰면 쉽게 가능

# %%
#value=df['name'].str.split(expand=True)
date_split2=stock['Date'].str.split('-', expand=True)
stock=pd.concat([stock, date_split2], axis=1)
stock
# Out:
#           Date  Close  Start   High    Low  Volume  Year Month Day     0   1  \
# 19  2022-06-01  11900  11800  12100  11750   32062  2022    06  01  2022  06
# 0   2018-07-02  10100  10850  10900  10000  137977  2018    07  02  2018  07
# 18  2022-06-04  11900  11900  12200  11700   25171  2022    06  04  2022  06
# 17  2022-06-05  12150  11800  12250  11800   42485  2022    06  05  2022  06
# 16  2021-06-07  11950  12200  12300  11900   49088  2021    06  07  2021  06
# 15  2020-06-08  11950  11950  12200  11800   59258  2020    06  08  2020  06
# 14  2020-06-11  11950  12000  12250  11950   62293  2020    06  11  2020  06
# 13  2020-06-12  13200  12200  13300  12050  558148  2020    06  12  2020  06
# 12  2018-06-14  13450  13200  13700  13150  347451  2018    06  14  2018  06
# 11  2018-06-15  13400  13600  13600  12900  201376  2018    06  15  2018  06
# 10  2018-06-18  12000  13400  13400  12000  309787  2018    06  18  2018  06
# 9   2018-06-19  11300  11850  11950  11300  180656  2018    06  19  2018  06
# 8   2018-06-20  11550  11200  11600  10900  308596  2018    06  20  2018  06
# 7   2018-06-21  11200  11350  11750  11200  133002  2018    06  21  2018  06
# 6   2018-06-22  11300  11250  11450  10750  134805  2018    06  22  2018  06
# 5   2018-06-25  11150  11400  11450  11000   55519  2018    06  25  2018  06
# 4   2018-06-26  10800  10900  11000  10700   63039  2018    06  26  2018  06
# 3   2018-06-27  10900  10800  11050  10500  133548  2018    06  27  2018  06
# 2   2018-06-28  10400  10900  10950  10150  155769  2018    06  28  2018  06
# 1   2018-06-29  10700  10550  10900   9990  170253  2018    06  29  2018  06
#
#      2
# 19  01
# 0   02
# 18  04
# 17  05
# 16  07
# 15  08
# 14  11
# 13  12
# 12  14
# 11  15
# 10  18
# 9   19
# 8   20
# 7   21
# 6   22
# 5   25
# 4   26
# 3   27
# 2   28
# 1   29

# %%
stock.rename(columns={0:'Year2', 1:'Month2', 2:'Day2'}, inplace=True)

# %%
# Date 컬럼을 datetime 자료형으로 변환
stock['Date']=pd.to_datetime(stock['Date'])

# %%
stock
# Out:
#          Date  Close  Start   High    Low  Volume  Year Month Day Year2  \
# 19 2022-06-01  11900  11800  12100  11750   32062  2022    06  01  2022
# 0  2018-07-02  10100  10850  10900  10000  137977  2018    07  02  2018
# 18 2022-06-04  11900  11900  12200  11700   25171  2022    06  04  2022
# 17 2022-06-05  12150  11800  12250  11800   42485  2022    06  05  2022
# 16 2021-06-07  11950  12200  12300  11900   49088  2021    06  07  2021
# 15 2020-06-08  11950  11950  12200  11800   59258  2020    06  08  2020
# 14 2020-06-11  11950  12000  12250  11950   62293  2020    06  11  2020
# 13 2020-06-12  13200  12200  13300  12050  558148  2020    06  12  2020
# 12 2018-06-14  13450  13200  13700  13150  347451  2018    06  14  2018
# 11 2018-06-15  13400  13600  13600  12900  201376  2018    06  15  2018
# 10 2018-06-18  12000  13400  13400  12000  309787  2018    06  18  2018
# 9  2018-06-19  11300  11850  11950  11300  180656  2018    06  19  2018
# 8  2018-06-20  11550  11200  11600  10900  308596  2018    06  20  2018
# 7  2018-06-21  11200  11350  11750  11200  133002  2018    06  21  2018
# 6  2018-06-22  11300  11250  11450  10750  134805  2018    06  22  2018
# 5  2018-06-25  11150  11400  11450  11000   55519  2018    06  25  2018
# 4  2018-06-26  10800  10900  11000  10700   63039  2018    06  26  2018
# 3  2018-06-27  10900  10800  11050  10500  133548  2018    06  27  2018
# 2  2018-06-28  10400  10900  10950  10150  155769  2018    06  28  2018
# 1  2018-06-29  10700  10550  10900   9990  170253  2018    06  29  2018
#
#    Month2 Day2
# 19     06   01
# 0      07   02
# 18     06   04
# 17     06   05
# 16     06   07
# 15     06   08
# 14     06   11
# 13     06   12
# 12     06   14
# 11     06   15
# 10     06   18
# 9      06   19
# 8      06   20
# 7      06   21
# 6      06   22
# 5      06   25
# 4      06   26
# 3      06   27
# 2      06   28
# 1      06   29
