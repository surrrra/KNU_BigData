# %% [markdown]
# # auto_mpg 데이터 전처리
#
# - 1. 단위 변환 => 컬럼 추가
# - 2. 자료형 검사 및 변환
# - 3. origin 컬럼에 대한 라벨 => 컬럼 추가

# %%
import pandas as pd

mpg=pd.read_csv('../Data/auto_mpg.csv')
mpg.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
# 요약 정보 확인
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
# 결측치 확인
mpg.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %% [markdown]
# ## 1. 단위 변환 => 컬럼 추가

# %%
mpg['km/L']=mpg['mpg']*0.425
mpg
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name    km/L
# 0            70       1  chevrolet chevelle malibu   7.650
# 1            70       1          buick skylark 320   6.375
# 2            70       1         plymouth satellite   7.650
# 3            70       1              amc rebel sst   6.800
# 4            70       1                ford torino   7.225
# ..          ...     ...                        ...     ...
# 393          82       1            ford mustang gl  11.475
# 394          82       2                  vw pickup  18.700
# 395          82       1              dodge rampage  13.600
# 396          82       1                ford ranger  11.900
# 397          82       1                 chevy s-10  13.175
#
# [398 rows x 10 columns]

# %% [markdown]
# ## 2. 자료형 검사 및 변환

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
#  9   km/L          398 non-null    float64
# dtypes: float64(4), int64(4), object(2)
# memory usage: 31.2+ KB

# %%
# horsepower가 object로 나와있음
mpg['horsepower'].unique()
# Out:
# array(['130', '165', '150', '140', '198', '220', '215', '225', '190',
#        '170', '160', '95', '97', '85', '88', '46', '87', '90', '113',
#        '200', '210', '193', '?', '100', '105', '175', '153', '180', '110',
#        '72', '86', '70', '76', '65', '69', '60', '80', '54', '208', '155',
#        '112', '92', '145', '137', '158', '167', '94', '107', '230', '49',
#        '75', '91', '122', '67', '83', '78', '52', '61', '93', '148',
#        '129', '96', '71', '98', '115', '53', '81', '79', '120', '152',
#        '102', '108', '68', '58', '149', '89', '63', '48', '66', '139',
#        '103', '125', '133', '138', '135', '142', '77', '62', '132', '84',
#        '64', '74', '116', '82'], dtype=object)

# %%
# horsepower가 object인 이유 : 중간에 '?'라는 값이 들어가있음
# '?' 값을 결측치로 바꿔주고자 함
import numpy as np
mpg['horsepower']=mpg['horsepower'].replace('?', np.NaN)

# %%
mpg['horsepower'].unique()
# Out:
# array(['130', '165', '150', '140', '198', '220', '215', '225', '190',
#        '170', '160', '95', '97', '85', '88', '46', '87', '90', '113',
#        '200', '210', '193', nan, '100', '105', '175', '153', '180', '110',
#        '72', '86', '70', '76', '65', '69', '60', '80', '54', '208', '155',
#        '112', '92', '145', '137', '158', '167', '94', '107', '230', '49',
#        '75', '91', '122', '67', '83', '78', '52', '61', '93', '148',
#        '129', '96', '71', '98', '115', '53', '81', '79', '120', '152',
#        '102', '108', '68', '58', '149', '89', '63', '48', '66', '139',
#        '103', '125', '133', '138', '135', '142', '77', '62', '132', '84',
#        '64', '74', '116', '82'], dtype=object)

# %%
mpg.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# km/L            0
# dtype: int64

# %%
mpg['horsepower'].fillna(0, inplace=True)   # horsepower의 결측치를 NaN으로 채우기

# %%
mpg.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# km/L            0
# dtype: int64

# %%
# horsepower 컬럼을 int형으로 자료형 변환하기
mpg['horsepower']=mpg['horsepower'].astype(int)

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    int32
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
#  9   km/L          398 non-null    float64
# dtypes: float64(4), int32(1), int64(4), object(1)
# memory usage: 29.7+ KB

# %% [markdown]
# ## 3. origin 컬럼에 대한 라벨 => 컬럼 추가

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0         130    3504          12.0
# 1  15.0          8         350.0         165    3693          11.5
# 2  18.0          8         318.0         150    3436          11.0
# 3  16.0          8         304.0         150    3433          12.0
# 4  17.0          8         302.0         140    3449          10.5
#
#    model year  origin                   car name   km/L
# 0          70       1  chevrolet chevelle malibu  7.650
# 1          70       1          buick skylark 320  6.375
# 2          70       1         plymouth satellite  7.650
# 3          70       1              amc rebel sst  6.800
# 4          70       1                ford torino  7.225

# %%
mpg['origin'].unique()
# Out:
# array([1, 3, 2], dtype=int64)

# %%
# car name의 첫 단어가 회사 이름이라고 생각해서 회사 이름의 고유값만 따로 빼옴
# 어느 나라인지 검색해보려고..

my_name=[]
for name in mpg[mpg['origin']==1]['car name'].unique():
    my_name.append(name.split(' ')[0])


print(len(my_name))
print(pd.Series(my_name).unique())
# Out:
# 187
# ['chevrolet' 'buick' 'plymouth' 'amc' 'ford' 'pontiac' 'dodge' 'chevy'
#  'hi' 'mercury' 'oldsmobile' 'chrysler' 'chevroelt' 'capri' 'cadillac']

# %%
# origin이 1이면 => US
# origin이 2면 => EU
# origin이 3이면 => JP
mpg['origin'].unique()
# Out:
# array([1, 3, 2], dtype=int64)

# %% [markdown]
# ## 원래 알고 있던 방법(안 배움)

# %%
cond1=mpg['origin']==1
cond2=mpg['origin']==2
cond3=mpg['origin']==3

mpg.loc[cond1, 'label']='US'
mpg.loc[cond2, 'label']='EU'
mpg.loc[cond3, 'label']='JP'

# %%
# origin의 값대로 label이 잘 들어갔는지 확인
mpg[mpg['origin']==1]['label'].unique(), mpg[mpg['origin']==2]['label'].unique(), mpg[mpg['origin']==3]['label'].unique()
# Out:
# (array(['US'], dtype=object),
#  array(['EU'], dtype=object),
#  array(['JP'], dtype=object))

# %%
# if mpg['origin']==1:
#     mpg['label']='US'
# elif mpg['origin']==2:
#     mpg['label']='EU'
# else:
#     mpg['label']='JP'

# 전혀 안되네

# %%
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0         130    3504          12.0
# 1    15.0          8         350.0         165    3693          11.5
# 2    18.0          8         318.0         150    3436          11.0
# 3    16.0          8         304.0         150    3433          12.0
# 4    17.0          8         302.0         140    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0          86    2790          15.6
# 394  44.0          4          97.0          52    2130          24.6
# 395  32.0          4         135.0          84    2295          11.6
# 396  28.0          4         120.0          79    2625          18.6
# 397  31.0          4         119.0          82    2720          19.4
#
#      model year  origin                   car name    km/L label
# 0            70       1  chevrolet chevelle malibu   7.650    US
# 1            70       1          buick skylark 320   6.375    US
# 2            70       1         plymouth satellite   7.650    US
# 3            70       1              amc rebel sst   6.800    US
# 4            70       1                ford torino   7.225    US
# ..          ...     ...                        ...     ...   ...
# 393          82       1            ford mustang gl  11.475    US
# 394          82       2                  vw pickup  18.700    EU
# 395          82       1              dodge rampage  13.600    US
# 396          82       1                ford ranger  11.900    US
# 397          82       1                 chevy s-10  13.175    US
#
# [398 rows x 11 columns]

# %% [markdown]
# ## 위랑 다른 방법(배운 내용 안)

# %%
mpg['new_label']=0

# %%
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0         130    3504          12.0
# 1    15.0          8         350.0         165    3693          11.5
# 2    18.0          8         318.0         150    3436          11.0
# 3    16.0          8         304.0         150    3433          12.0
# 4    17.0          8         302.0         140    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0          86    2790          15.6
# 394  44.0          4          97.0          52    2130          24.6
# 395  32.0          4         135.0          84    2295          11.6
# 396  28.0          4         120.0          79    2625          18.6
# 397  31.0          4         119.0          82    2720          19.4
#
#      model year  origin                   car name    km/L label  new_label
# 0            70       1  chevrolet chevelle malibu   7.650    US          0
# 1            70       1          buick skylark 320   6.375    US          0
# 2            70       1         plymouth satellite   7.650    US          0
# 3            70       1              amc rebel sst   6.800    US          0
# 4            70       1                ford torino   7.225    US          0
# ..          ...     ...                        ...     ...   ...        ...
# 393          82       1            ford mustang gl  11.475    US          0
# 394          82       2                  vw pickup  18.700    EU          0
# 395          82       1              dodge rampage  13.600    US          0
# 396          82       1                ford ranger  11.900    US          0
# 397          82       1                 chevy s-10  13.175    US          0
#
# [398 rows x 12 columns]

# %%
for i in mpg.index:
    if mpg.loc[i, 'origin']==1:
        mpg.loc[i, 'new_label']='US'
    elif mpg.loc[i, 'origin']==2:
        mpg.loc[i, 'new_label']='EU'
    elif mpg.loc[i, 'origin']==3:
        mpg.loc[i, 'new_label']='JP'

# %%
mpg
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0         130    3504          12.0
# 1    15.0          8         350.0         165    3693          11.5
# 2    18.0          8         318.0         150    3436          11.0
# 3    16.0          8         304.0         150    3433          12.0
# 4    17.0          8         302.0         140    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0          86    2790          15.6
# 394  44.0          4          97.0          52    2130          24.6
# 395  32.0          4         135.0          84    2295          11.6
# 396  28.0          4         120.0          79    2625          18.6
# 397  31.0          4         119.0          82    2720          19.4
#
#      model year  origin                   car name    km/L label new_label
# 0            70       1  chevrolet chevelle malibu   7.650    US        US
# 1            70       1          buick skylark 320   6.375    US        US
# 2            70       1         plymouth satellite   7.650    US        US
# 3            70       1              amc rebel sst   6.800    US        US
# 4            70       1                ford torino   7.225    US        US
# ..          ...     ...                        ...     ...   ...       ...
# 393          82       1            ford mustang gl  11.475    US        US
# 394          82       2                  vw pickup  18.700    EU        EU
# 395          82       1              dodge rampage  13.600    US        US
# 396          82       1                ford ranger  11.900    US        US
# 397          82       1                 chevy s-10  13.175    US        US
#
# [398 rows x 12 columns]

# %%
mpg[mpg['origin']==1]['new_label'].unique(), mpg[mpg['origin']==2]['new_label'].unique(), mpg[mpg['origin']==3]['new_label'].unique()
# Out:
# (array(['US'], dtype=object),
#  array(['EU'], dtype=object),
#  array(['JP'], dtype=object))
